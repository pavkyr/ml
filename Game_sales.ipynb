# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c286d710-03dd-4620-bf65-197d32178a53" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c286d710-03dd-4620-bf65-197d32178a53">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Video_Games_Sales_as_at_22_Dec_2016.csv to Video_Games_Sales_as_at_22_Dec_2016 (1).csv

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uploaded['Video_Games_Sales_as_at_22_Dec_2016.csv']))

# %%
df.head()
df.shape
# Out:
# (16719, 16)

# %%
df=df.dropna(axis=0)
df.shape
# Out:
# (6825, 16)

# %%
df.head()
# Out:
#                     Name Platform  Year_of_Release  ... User_Count Developer  Rating
# 0             Wii Sports      Wii           2006.0  ...      322.0  Nintendo       E
# 2         Mario Kart Wii      Wii           2008.0  ...      709.0  Nintendo       E
# 3      Wii Sports Resort      Wii           2009.0  ...      192.0  Nintendo       E
# 6  New Super Mario Bros.       DS           2006.0  ...      431.0  Nintendo       E
# 7               Wii Play      Wii           2006.0  ...      129.0  Nintendo       E
#
# [5 rows x 16 columns]

# %%
useful_cols = ['Name', 'Platform', 'Year_of_Release', 'Genre', 
               'Global_Sales', 'Critic_Score', 'Critic_Count',
               'User_Score', 'User_Count', 'Rating']

# %%
df[useful_cols].head()
# Out:
#                     Name Platform  ...  User_Count Rating
# 0             Wii Sports      Wii  ...       322.0      E
# 2         Mario Kart Wii      Wii  ...       709.0      E
# 3      Wii Sports Resort      Wii  ...       192.0      E
# 6  New Super Mario Bros.       DS  ...       431.0      E
# 7               Wii Play      Wii  ...       129.0      E
#
# [5 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

df.groupby('Year_of_Release')['NA_Sales','EU_Sales','JP_Sales','Other_Sales',].sum().plot.line()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   if __name__ == '__main__':

# %%
df.groupby('Year_of_Release')['NA_Sales','EU_Sales','JP_Sales','Other_Sales',].sum().plot(kind='bar', rot=45)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
platform_genre_sales = df.pivot_table(
                        index='Platform', 
                        columns='Genre', 
                        values='Global_Sales', 
                        aggfunc=sum).fillna(0).applymap(float)

# %%
platform_genre_sales
# Out:
# Genre     Action  Adventure  Fighting  ...  Simulation  Sports  Strategy
# Platform                               ...
# 3DS        30.81       2.00      2.63  ...       16.08    2.20      0.94
# DC          0.00       1.33      0.56  ...        0.52    1.09      0.00
# DS         42.43       8.83      3.37  ...       42.71    6.01      8.00
# GBA        23.21       4.54      3.28  ...        2.03    5.93      3.34
# GC         29.99       4.56     15.81  ...        8.39   19.91      3.45
# PC         25.45       1.42      0.13  ...       40.34    6.54     25.37
# PS         54.93       1.10     18.91  ...        1.67   20.75      0.25
# PS2       238.73      10.74     64.72  ...       34.01  191.88      8.21
# PS3       262.38      16.18     47.83  ...        7.91   98.20      3.19
# PS4        76.92       3.09      6.86  ...        0.72   55.16      0.46
# PSP        43.92       2.81     12.36  ...        4.61   25.34      3.40
# ...

# %%
df.groupby('Genre')['Global_Sales'].median().plot(kind='bar',rot=45)

# %% [markdown]
# временные ряды

# %%
import numpy as np
data=pd.DataFrame(columns=['Date','Price'])
data['Date']=pd.date_range('1/1/2019','12,28,2021',freq='D')
data['Price']=np.random.normal(500,600,1066)

# %%
data['Price']=data.Price.apply(lambda x: int(x))

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x=data['Date'],y=data['Price'])
sns.lineplot(x=data['Date'],y=data['Price'].rolling(30,min_periods=1).mean())

# %%
sns.displot(data['Price'])

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d510790b-8edf-4043-b7c0-012391795741" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d510790b-8edf-4043-b7c0-012391795741">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving coin_Bitcoin.csv to coin_Bitcoin.csv

# %%
bit = pd.read_csv(io.BytesIO(uploaded['coin_Bitcoin.csv']),parse_dates=['Date'])

# %%
bit.dtypes
# Out:
# SNo                   int64
# Name                 object
# Symbol               object
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Marketcap           float64
# dtype: object

# %%
bit=bit.drop(['SNo','Name','Symbol'],axis=1)

# %%
bit.head()
# Out:
#                  Date        High         Low  ...       Close  Volume     Marketcap
# 0 2013-04-29 23:59:59  147.488007  134.000000  ...  144.539993     0.0  1.603769e+09
# 1 2013-04-30 23:59:59  146.929993  134.050003  ...  139.000000     0.0  1.542813e+09
# 2 2013-05-01 23:59:59  139.889999  107.720001  ...  116.989998     0.0  1.298955e+09
# 3 2013-05-02 23:59:59  125.599998   92.281898  ...  105.209999     0.0  1.168517e+09
# 4 2013-05-03 23:59:59  108.127998   79.099998  ...   97.750000     0.0  1.085995e+09
#
# [5 rows x 7 columns]

# %%
sns.lineplot(x=bit['Date'],y=bit['Close'])

# %%
print(bit[['Date','Close']].head(3))
print(bit[['Date','Close']].tail(3))
# Out:
#                  Date       Close
# 0 2013-04-29 23:59:59  144.539993
# 1 2013-04-30 23:59:59  139.000000
# 2 2013-05-01 23:59:59  116.989998
#                     Date         Close
# 2988 2021-07-04 23:59:59  35287.779766
# 2989 2021-07-05 23:59:59  33746.002456
# 2990 2021-07-06 23:59:59  34235.193451

# %%
from statsmodels.tsa.stattools import adfuller
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
dftest = adfuller(bit['Date'], autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Observations Used'])
for key, value in dftest[4].items():
  dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-b46c4f4459a2> in <module>()
# ----> 1 dftest = adfuller(bit['Date'], autolag='AIC')
#       2 dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Observations Used'])
#       3 for key, value in dftest[4].items():
#       4   dfoutput['Critical Value (%s)'%key] = value
#       5 print(dfoutput)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     255         if not regresults:
#     256             icbest, bestlag = _autolag(OLS, xdshort, fullRHS, startlag,
# --> 257                                        maxlag, autolag)
#     258         else:
#     259             icbest, bestlag, alres = _autolag(OLS, xdshort, fullRHS, startlag,
#
# ...
